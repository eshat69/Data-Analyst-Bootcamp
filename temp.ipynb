# %% [markdown]
# # libraries for Logistic regression

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %% [markdown]
# # libraries for Linear Regression

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# read dataset 
df = pd.read_csv("dataset.csv")
df.head()

# %%
df["target value"].value_counts()

# %%
# count row col
df.shape

# %%
# check for null value in each column
df.isna().sum()

# %%
# check the duplicate rows
df[df.duplicated()]

# %%
# drop the duplicate values
df = df.drop_duplicates()

# %%
# check the data types of columns 
df.info()

# %%
# check min, max , std ,mean , count for better analysis
df.describe()

# %%
# FIND  co relation between each columns 
df.corr()

# %% [markdown]
# # ENCODE THE CATEGORIZED DATA INTO NUMARIC DATA

# %%
from sklearn.preprocessing import LabelEncoder
# Initialize the encoder
le = LabelEncoder()
df["col"]= le.fit_transform(df["col"])
df.head()

# %%
# PAIR BETWEEN EACH COLUMN 
sns.pairplot(df)

# %%
sns.boxplot(df["target col"])

# %%
# groupby if require to visulized multiple data 
df.groupby("col1")["ciol"].value_counts().plot(kind="bar")

# %%
df.loc[1st pos : last pos ]
df.iloc[starting index : ending index]

# %%
# Independent Variables (x)
x = df.drop(columns=["target col "])
# Dependent Variable (y)
y = df["target col"]

# %%
from sklearn.model_selection import train_test_split
# saperate the train and test 
# 20% test data 
# random state help from shaffle 
Xtrain, Xtest, Ytrain, Ytest= train_test_split(x,y, test_size=.2, random_state=42)
# check splited shape of train and test 
Xtrain.shape,Ytrain.shape, Xtest.shape,  Ytest.shape

# %% [markdown]
# # choose the model is required for
# if true/false use Logistic Regression
# elif continous use Linear Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
log_reg = LogisticRegression() 
log_reg.fit(Xtrain, Ytrain)

# %%
y_pred = log_reg.predict(Xtest)

# %%
print(f"Accuracy: {accuracy_score(Xtest, y_pred)}")

# %%
print(classification_report(Xtest, y_pred))

# %%
cm = confusion_matrix(Xtest, y_pred)
cm

# %%
sns.heatmap(cm, annot=True, fmt="g")

# %%
pred_proba = log_reg.predict_proba(Xtest)
pred_proba

# %%
Xtest.value_counts()

# %%
Xtest.head()

# %%
model.predict([[Xtrain]])

# %%
from sklearn.model_selection import train_test_split
# saperate the train and test 
# 20% test data 
# random state help from shaffle 
Xtrain, Xtest, Ytrain, Ytest= train_test_split(x,y, test_size=.2, random_state=42)
# check splited shape of train and test 
Xtrain.shape,Ytrain.shape, Xtest.shape,  Ytest.shape

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

lin_reg = LinearRegression()
model = lr.fit(Xtrain, Ytrain)

# %%
model.score(Xtrain, Ytrain)

# %%
model.score(Xtest, Ytest)

# %%
print(model.score(Xtrain, Ytrain)*100)
print(model.score(Xtest, Ytest)*100)

# %%
df["prediction"] = model.predict(x)
df.head()

# %%
df["error"]= df["target"]- df["prediction"]
df.head()

# %%
y_pred = model.predict(Xtest)
mae = mean_absolute_error(Ytest, y_pred)
mae

# %%
mse = mean_squared_error(Ytest, y_pred)
print(mse)

# %%
# accuracy measure
r_sc = r2_score(Ytest, y_pred)
r_sc
